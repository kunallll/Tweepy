# %% [markdown]
# # Tweepy
#
# Tweepy is an open source Python package that gives you a very convenient way to access the Twitter API with Python. Tweepy includes a set of classes and methods that represent Twitter’s models and API endpoints, and it transparently handles various implementation details, such as:
#
# 1. Data encoding and decoding
# 2. HTTP requests
# 3. Results pagination
# 4. OAuth authentication
# 5. Rate limits
# 6. Streams

# %%
import tweepy
import textblob
import re
import access_variables
import pandas as pd

# %% [markdown]
# ## Basics(tweepy & twitter)
#
# Twitter api provides a developer(Or user) with a Consumer key, Consumer secret, Access Token, access token secret which authenticates the user to use the api. The auth variable below is used to authenticate the user to use the twitter data in the api.

# %%
auth = tweepy.OAuthHandler(access_variables.CONSUMER_KEY, access_variables.CONSUMER_SECRET)
auth.set_access_token(access_variables.ACCESS_TOKEN, access_variables.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# ## Extracting the trending list:
#
# The tweepy package contains a function called "trends_place" that gives the trending list of the particular place. It takes the WOEID of the place as an arguement. A WOEID (Where On Earth IDentifier) is a unique 32-bit reference identifier, originally defined by GeoPlanet and now assigned by Yahoo!, that identifies any feature on Earth. In 2009, Yahoo!
#
# Below, the WOEID being used is of the city Chennai(Country India, WOEID: 2295424).
#
# It gives an JSON content which provides the details of each trending topic. These details are:
# 1. Name, trending topic's name
# 2. Url, twitter link of the topic
# 3. Query, the query name of the topic
# 4. Tweet volume, Tweet Volume: Twitter Hashtag volume includes total number of tweets, retweets and replies. Reach: Twitter Hashtag reach is defined as the total number of Twitter accounts to which the hashtag/keyword/@account has reached.

# %%
trends = api.trends_place(2295424)
trends
# Out:
# [{'trends': [{'name': '#Master',
#     'url': 'http://twitter.com/search?q=%23Master',
#     'promoted_content': None,
#     'query': '%23Master',
#     'tweet_volume': 255634},
#    {'name': 'Chennai',
#     'url': 'http://twitter.com/search?q=Chennai',
#     'promoted_content': None,
#     'query': 'Chennai',
#     'tweet_volume': 13687},
#    {'name': '#TrueWorship_Is_Necessary',
#     'url': 'http://twitter.com/search?q=%23TrueWorship_Is_Necessary',
#     'promoted_content': None,
#     'query': '%23TrueWorship_Is_Necessary',
#     'tweet_volume': 82993},
#    {'name': '#CBIForPalghar',
#     'url': 'http://twitter.com/search?q=%23CBIForPalghar',
#     'promoted_content': None,
#     'query': '%23CBIForPalghar',
#     'tweet_volume': 94727},
#    {'name': '#TwitterDown',
#     'url': 'http://twitter.com/search?q=%23TwitterDown',
#     'promoted_content': None,
#     'query': '%23TwitterDown',
#     'tweet_volume': None},
#    {'name': '#GetWellSoonSPBSIR',
#     'url': 'http://twitter.com/search?q=%23GetWellSoonSPBSIR',
#     'promoted_content': None,
#     'query': '%23GetWellSoonSPBSIR',
#     'tweet_volume': 21846},
#    {'name': 'Payal Ghosh',
#     'url': 'http://twitter.com/search?q=%22Payal+Ghosh%22',
#     'promoted_content': None,
#     'query': '%22Payal+Ghosh%22',
#     'tweet_volume': None},
#    {'name': 'The Gone Game',
#     'url': 'http://twitter.com/search?q=%22The+Gone+Game%22',
#     'promoted_content': None,
#     'query': '%22The+Gone+Game%22',
#     'tweet_volume': None},
#    {'name': 'trell keh jo kehna hai',
#     'url': 'http://twitter.com/search?q=%22trell+keh+jo+kehna+hai%22',
#     'promoted_content': None,
#     'query': '%22trell+keh+jo+kehna+hai%22',
#     'tweet_volume': None},
#    {'name': 'Balasaheb',
#     'url': 'http://twitter.com/search?q=Balasaheb',
#     'promoted_content': None,
#     'query': 'Balasaheb',
#     'tweet_volume': None},
#    {'name': 'Hrithik',
#     'url': 'http://twitter.com/search?q=Hrithik',
#     'promoted_content': None,
#     'query': 'Hrithik',
#     'tweet_volume': 10105},
#    {'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 80093},
#    {'name': '#PrashantBhushan',
#     'url': 'http://twitter.com/search?q=%23PrashantBhushan',
#     'promoted_content': None,
#     'query': '%23PrashantBhushan',
#     'tweet_volume': 39708},
#    {'name': '#ArmaanMalikStreamingParty',
#     'url': 'http://twitter.com/search?q=%23ArmaanMalikStreamingParty',
#     'promoted_content': None,
#     'query': '%23ArmaanMalikStreamingParty',
#     'tweet_volume': None},
#    {'name': '#Nenjame',
#     'url': 'http://twitter.com/search?q=%23Nenjame',
#     'promoted_content': None,
#     'query': '%23Nenjame',
#     'tweet_volume': 32103},
#    {'name': '#HMxMyntraTurnsOne',
#     'url': 'http://twitter.com/search?q=%23HMxMyntraTurnsOne',
#     'promoted_content': None,
#     'query': '%23HMxMyntraTurnsOne',
#     'tweet_volume': None},
#    {'name': '#RaiseYourWillpower',
#     'url': 'http://twitter.com/search?q=%23RaiseYourWillpower',
#     'promoted_content': None,
#     'query': '%23RaiseYourWillpower',
#     'tweet_volume': None},
#    {'name': '#WeMissYouShehnaaz',
#     'url': 'http://twitter.com/search?q=%23WeMissYouShehnaaz',
#     'promoted_content': None,
#     'query': '%23WeMissYouShehnaaz',
#     'tweet_volume': 51734},
#    {'name': '#ChinaAgainstMinorities',
#     'url': 'http://twitter.com/search?q=%23ChinaAgainstMinorities',
#     'promoted_content': None,
#     'query': '%23ChinaAgainstMinorities',
#     'tweet_volume': 32945},
#    {'name': '#hunger_strike_SSCcglresult',
#     'url': 'http://twitter.com/search?q=%23hunger_strike_SSCcglresult',
#     'promoted_content': None,
#     'query': '%23hunger_strike_SSCcglresult',
#     'tweet_volume': None},
#    {'name': '#ResignParambirSingh',
#     'url': 'http://twitter.com/search?q=%23ResignParambirSingh',
#     'promoted_content': None,
#     'query': '%23ResignParambirSingh',
#     'tweet_volume': 196192},
#    {'name': '#TheSnyderCut',
#     'url': 'http://twitter.com/search?q=%23TheSnyderCut',
#     'promoted_content': None,
#     'query': '%23TheSnyderCut',
#     'tweet_volume': None},
#    {'name': '#BellBottom',
#     'url': 'http://twitter.com/search?q=%23BellBottom',
#     'promoted_content': None,
#     'query': '%23BellBottom',
#     'tweet_volume': None},
#    {'name': '#SwachhSurvekshan2020',
#     'url': 'http://twitter.com/search?q=%23SwachhSurvekshan2020',
#     'promoted_content': None,
#     'query': '%23SwachhSurvekshan2020',
#     'tweet_volume': 16682},
#    {'name': '#hindustanibhau',
#     'url': 'http://twitter.com/search?q=%23hindustanibhau',
#     'promoted_content': None,
#     'query': '%23hindustanibhau',
#     'tweet_volume': None},
#    {'name': '#SaraAliKhan',
#     'url': 'http://twitter.com/search?q=%23SaraAliKhan',
#     'promoted_content': None,
#     'query': '%23SaraAliKhan',
#     'tweet_volume': 12647},
#    {'name': '#gmaildown',
#     'url': 'http://twitter.com/search?q=%23gmaildown',
#     'promoted_content': None,
#     'query': '%23gmaildown',
#     'tweet_volume': None},
#    {'name': '#प्रशांतभूषण',
#     'url': 'http://twitter.com/search?q=%23%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%B6%E0%A4%BE%E0%A4%82%E0%A4%A4%E0%A4%AD%E0%A5%82%E0%A4%B7%E0%A4%A3',
#     'promoted_content': None,
#     'query': '%23%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%B6%E0%A4%BE%E0%A4%82%E0%A4%A4%E0%A4%AD%E0%A5%82%E0%A4%B7%E0%A4%A3',
#     'tweet_volume': None},
#    {'name': '#RemembringRajivGandhi',
#     'url': 'http://twitter.com/search?q=%23RemembringRajivGandhi',
#     'promoted_content': None,
#     'query': '%23RemembringRajivGandhi',
#     'tweet_volume': None},
#    {'name': '#SantNarayanGuruJayanti',
#     'url': 'http://twitter.com/search?q=%23SantNarayanGuruJayanti',
#     'promoted_content': None,
#     'query': '%23SantNarayanGuruJayanti',
#     'tweet_volume': None},
#    {'name': '#RIPSUBHASRI_SAVE30LAKH',
#     'url': 'http://twitter.com/search?q=%23RIPSUBHASRI_SAVE30LAKH',
#     'promoted_content': None,
#     'query': '%23RIPSUBHASRI_SAVE30LAKH',
#     'tweet_volume': 925499},
#    {'name': '#muagainststudents',
#     'url': 'http://twitter.com/search?q=%23muagainststudents',
#     'promoted_content': None,
#     'query': '%23muagainststudents',
#     'tweet_volume': None},
#    {'name': '#LaabamTrailer',
#     'url': 'http://twitter.com/search?q=%23LaabamTrailer',
#     'promoted_content': None,
#     'query': '%23LaabamTrailer',
#     'tweet_volume': None},
#    {'name': '#WorldMosquitoDay',
#     'url': 'http://twitter.com/search?q=%23WorldMosquitoDay',
#     'promoted_content': None,
#     'query': '%23WorldMosquitoDay',
#     'tweet_volume': None},
#    {'name': '#AkModel4Uttarakhand',
#     'url': 'http://twitter.com/search?q=%23AkModel4Uttarakhand',
#     'promoted_content': None,
#     'query': '%23AkModel4Uttarakhand',
#     'tweet_volume': None},
#    {'name': '#Dikkiloona',
#     'url': 'http://twitter.com/search?q=%23Dikkiloona',
#     'promoted_content': None,
#     'query': '%23Dikkiloona',
#     'tweet_volume': 17491},
#    {'name': '#Indore',
#     'url': 'http://twitter.com/search?q=%23Indore',
#     'promoted_content': None,
#     'query': '%23Indore',
#     'tweet_volume': None},
#    {'name': '#RajivGandhi76',
#     'url': 'http://twitter.com/search?q=%23RajivGandhi76',
#     'promoted_content': None,
#     'query': '%23RajivGandhi76',
#     'tweet_volume': None},
#    {'name': '#JanaDhwani',
#     'url': 'http://twitter.com/search?q=%23JanaDhwani',
#     'promoted_content': None,
#     'query': '%23JanaDhwani',
#     'tweet_volume': None},
#    {'name': '#VOnPrime',
#     'url': 'http://twitter.com/search?q=%23VOnPrime',
#     'promoted_content': None,
#     'query': '%23VOnPrime',
#     'tweet_volume': 17231},
#    {'name': '#IslamicNewYear',
#     'url': 'http://twitter.com/search?q=%23IslamicNewYear',
#     'promoted_content': None,
#     'query': '%23IslamicNewYear',
#     'tweet_volume': None},
#    {'name': '#plfixtures',
#     'url': 'http://twitter.com/search?q=%23plfixtures',
#     'promoted_content': None,
#     'query': '%23plfixtures',
#     'tweet_volume': 37925},
#    {'name': '#GaneshChaturthi',
#     'url': 'http://twitter.com/search?q=%23GaneshChaturthi',
#     'promoted_content': None,
#     'query': '%23GaneshChaturthi',
#     'tweet_volume': None},
#    {'name': '#louiscometoindia',
#     'url': 'http://twitter.com/search?q=%23louiscometoindia',
#     'promoted_content': None,
#     'query': '%23louiscometoindia',
#     'tweet_volume': None},
#    {'name': '#MyCleanIndia',
#     'url': 'http://twitter.com/search?q=%23MyCleanIndia',
#     'promoted_content': None,
#     'query': '%23MyCleanIndia',
#     'tweet_volume': None},
#    {'name': '#13YearsOfDMG',
#     'url': 'http://twitter.com/search?q=%2313YearsOfDMG',
#     'promoted_content': None,
#     'query': '%2313YearsOfDMG',
#     'tweet_volume': None},
#    {'name': '#oppof17pro',
#     'url': 'http://twitter.com/search?q=%23oppof17pro',
#     'promoted_content': None,
#     'query': '%23oppof17pro',
#     'tweet_volume': None}],
#   'as_of': '2020-08-20T14:29:46Z',
#   'created_at': '2020-08-20T14:25:55Z',
#   'locations': [{'name': 'Chennai', 'woeid': 2295424}]}]

# %% [markdown]
# ## Storing the trending list:
#
# The JSON provides us with various other properties of the tweets, but here only the trending topic and tweet volumne is considered. A csv file with 2 columns namely:
# 1. Trending topic
# 2. Tweet volumne
#
# stores the properties of the trending topics above mentioned.

# %%
trend_list = []

for trend in trends[0]['trends']:
    trend_detail_list = []
    trend_detail_list.append(trend['name'])
    trend_detail_list.append(trend['tweet_volume'])
    trend_list.append(trend_detail_list)
    
pd.DataFrame(trend_list, columns=['Trending topic', 'Tweet volumne']).to_csv('trending_list.csv', index=False)

# %% [markdown]
# The next files being stored are the tweets in each trending topic. A total of 30 tweets from each trending topics will be taken. The csv file has the following columns:
# 1. Tweet contents/Tweet
# 2. Sentiment of tweet/Sentiment

# %%
tweets = []
for trend in trend_list:
    for tweet in tweepy.Cursor(api.search, q=trend[0], rpp=100, result_type="recent", include_entities=True, lang="en").items(30):
            tweet_list = []
            x = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split())
            sentiment = textblob.TextBlob(x).sentiment.polarity
            tweet_list.append(x)
            tweet_list.append(sentiment)
            tweets.append(tweet_list)
    pd.DataFrame(tweets, columns=['Tweets', 'Sentiment']).to_csv(trend[0]+'.csv', index=False)

# %% [markdown]
# ### Sources:
# 1. www.google.com
# 2. https://realpython.com/twitter-bot-python-tweepy/#what-is-tweepy
# 3. https://www.youtube.com/watch?v=dvAurfBB6Jk&t=2299s
# 4. https://www.tweepy.org/
